# %%
import pandas as pd
import matplotlib 
from matplotlib import pyplot as plt

# financial data
financial_data = {'Year': [2021,2022,2023,2024], 'Revenue': [10, 12, 11, 15]}
df = pd.DataFrame(financial_data)
df.plot(x='Year', y='Revenue', kind='line')
plt.show()

# %%
#wheater data
wheater_data = pd.DataFrame({'Temperature':[22,24,19,25]})
wheater_data.hist(bins=3)
plt.show()
