# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
categories = ["A", "B", "C", "D"]
values = [3, 7, 2, 5]

plt.bar(categories, values)
plt.title("Simple Bar Graphic")
plt.show()
